# %%
import pandas as pd
import numpy as np
import time, random, math
import scipy.io
from scipy import misc
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use('ggplot')
from pandas.tools.plotting import andrews_curves

# %%
train_values = pd.read_csv('data/train_values.csv')
train_labels = pd.read_csv('data/train_labels.csv')
test_values = pd.read_csv('data/test_values.csv')

# %%
print('train_values.shape', train_values.shape)
print('train_labels.shape', train_labels.shape)
print('test_values.shape', test_values.shape)
# Out:
# train_values.shape (17107, 298)
# train_labels.shape (17107, 2)
# test_values.shape (9192, 298)

# %%
print(train_values.describe())
# Out:
#              row_id  academics__program_assoc_agriculture  \
# count  17107.000000                          16393.000000
# mean   13259.717835                              0.074483
# std     7577.385374                              0.266713
# min        0.000000                              0.000000
# 25%     6715.500000                              0.000000
# 50%    13290.000000                              0.000000
# 75%    19835.500000                              0.000000
# max    26296.000000                              2.000000
#
#        academics__program_assoc_architecture  \
# count                           16393.000000
# mean                                0.019582
# std                                 0.139876
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 2.000000
#
#        academics__program_assoc_biological  \
# count                         16393.000000
# mean                              0.136827
# std                               0.366191
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               2.000000
#
#        academics__program_assoc_business_marketing  \
# count                                 16393.000000
# mean                                      0.457390
# std                                       0.561303
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       1.000000
# max                                       2.000000
#
#        academics__program_assoc_communication  \
# count                            16393.000000
# mean                                 0.070579
# std                                  0.262015
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  2.000000
#
#        academics__program_assoc_communications_technology  \
# count                                       16393.000000
# mean                                            0.072897
# std                                             0.263703
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             2.000000
#
#        academics__program_assoc_computer  \
# count                       16393.000000
# mean                            0.313243
# std                             0.490173
# min                             0.000000
# 25%                             0.000000
# 50%                             0.000000
# 75%                             1.000000
# max                             2.000000
#
#        academics__program_assoc_construction  \
# count                           16393.000000
# mean                                0.116269
# std                                 0.352983
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 2.000000
#
#        academics__program_assoc_education      ...        \
# count                        16393.000000      ...
# mean                             0.188617      ...
# std                              0.414388      ...
# min                              0.000000      ...
# 25%                              0.000000      ...
# 50%                              0.000000      ...
# 75%                              0.000000      ...
# max                              2.000000      ...
#
#        student__retention_rate_lt_four_year_full_time  \
# count                                     8684.000000
# mean                                         0.659676
# std                                          0.171571
# min                                          0.000000
# 25%                                          0.550000
# 50%                                          0.656950
# 75%                                          0.782125
# max                                          1.000000
#
#        student__retention_rate_lt_four_year_part_time  \
# count                                     5454.000000
# mean                                         0.518777
# std                                          0.241369
# min                                          0.000000
# 25%                                          0.355950
# 50%                                          0.467100
# 75%                                          0.691350
# max                                          1.000000
#
#        student__share_25_older  student__share_first_time_full_time  \
# count             11981.000000                         10148.000000
# mean                  0.402165                             0.548404
# std                   0.215534                             0.250842
# min                   0.000500                             0.000000
# 25%                   0.244800                             0.354900
# 50%                   0.402500                             0.556600
# 75%                   0.554500                             0.745900
# max                   1.000000                             1.000000
#
#        student__share_firstgeneration  \
# count                    16421.000000
# mean                         0.480284
# std                          0.125933
# min                          0.061885
# 25%                          0.406995
# 50%                          0.506522
# 75%                          0.563441
# max                          0.952494
#
#        student__share_firstgeneration_parents_highschool  \
# count                                       14300.000000
# mean                                            0.441961
# std                                             0.093237
# min                                             0.072131
# 25%                                             0.394527
# 50%                                             0.458540
# 75%                                             0.499523
# max                                             0.916865
#
#        student__share_firstgeneration_parents_middleschool  \
# count                                          84.000000
# mean                                            0.343816
# std                                             0.092246
# min                                             0.165217
# 25%                                             0.289393
# 50%                                             0.309442
# 75%                                             0.390234
# max                                             0.775618
#
#        student__share_firstgeneration_parents_somecollege  \
# count                                       15532.000000
# mean                                            0.527212
# std                                             0.123921
# min                                             0.047506
# 25%                                             0.442428
# 50%                                             0.501171
# 75%                                             0.600000
# max                                             0.938115
#
#        student__share_independent_students  student__size
# count                         16747.000000   16207.000000
# mean                              0.541637    2809.972728
# std                               0.242244    6033.976369
# min                               0.006929       0.000000
# 25%                               0.361719     221.000000
# 50%                               0.592857     760.000000
# 75%                               0.736535    2645.000000
# max                               0.989709  249604.000000
#
# [8 rows x 289 columns]

# %%
train_labels.describe()
# Out:
#              row_id        income
# count  17107.000000  17107.000000
# mean   13259.717835     30.592003
# std     7577.385374     11.302597
# min        0.000000      9.400000
# 25%     6715.500000     23.000000
# 50%    13290.000000     28.700000
# 75%    19835.500000     35.600000
# max    26296.000000    151.500000

# %%
fig = plt.figure()
plt.hist(train_labels['income'])
plt.show()
